# %%
#Librerías
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import h5py

# %%
#Constantes Físicas
h = 6.62607015e-34 #Constante de Planck (J·s)
c = 2.99792458e8 #Velocidad de la luz (m/s)
k_B = 1.380649e-23 #Constante de Boltzmann (J/K)

# %%
#Funciones
def Lambda0_Dom(z, lambda_instrument_data):
    '''
    Esta función crea el dominio de longitud de onda sin redshift para el espectro, es decir,
    el que se mediría si la funte de radiación no se moviera respecto a nosotros.
    ---
    Argumentos:
    z: Redshift del espectro a generar.
    lambda_instrument_data: Dominio de valores de longitud de onda en los que mide un mismo
                            instrumento.
    '''
    return lambda_instrument_data/(1+z)

def blackbody(lambda0_data, T):
    '''
    Esta función retorna los datos de radiancia de un cuerpo negro a temperatura T para las
    longitudes de onda consideradas.
    ---
    Argumentos:
    lambda0_data: Dominio de valores de longitud de onda emitidos por la fuente.
    T: Temperatura del cuerpo negro.
    '''
    return ((2*h*c**2)/(lambda0_data**5)) / (np.exp((h*c)/(lambda0_data*k_B*T))-1)

def H_lines(lambda0_data, Blackbody_data):
    '''
    Esta función agrega las principales líneas de absorción del hidrógeno a un espectro de
    cuerpo negro.
    ---
    Argumentos:
    lambda0_data: Dominio de valores de longitud de onda emitidos por la fuente.
    Blackbody_data: Datos de radiancia de cuerpo negro emitida por la fuente.
    '''
    depth = 0.7 #profundidad de la línea de absorción (valores entre 0 y 1)
    gamma = 1e-9 #grosor de la línea de absorción
    H_alpha = depth*gamma**2 / ((lambda0_data - 656.21e-9  )**2 + gamma**2)
    H_beta = depth*gamma**2 / ((lambda0_data - 486.08e-9  )**2 + gamma**2)
    H_gamma = depth*gamma**2 / ((lambda0_data - 434.00e-9  )**2 + gamma**2)
    H_delta = depth*gamma**2 / ((lambda0_data - 410.13e-9  )**2 + gamma**2)
    lorentzian_profile = H_alpha + H_beta + H_gamma + H_delta
    return Blackbody_data * (1 - lorentzian_profile)

def noise_generator(emission_data):
    '''
    Esta función agrega ruido gaussiano a un espectro.
    ---
    Argumentos:
    emission_data: Datos de radiancia emitida por la fuente (cuerpo negro + líneas).
    '''
    return emission_data + np.random.normal(0, standar_dev, len(emission_data))

def spectrum_generator(T, z, lambda_instrument_data):
    '''
    Esta función genera un espectro sintético de una fuente a temperatura T y con redshift
    z. El espectro corresponde al de un cuerpo negro al cual se le adicionan las cuatro primeras
    líneas de absorción del Hidrógeno y un ruido gaussiano. Este espectro está limitado al
    dominio de longitudes de onda que puede medir un mismo instrumento.
    ---
    Argumentos:
    T: Temperatura de la fuente.
    z: Redshift de la fuente.
    lambda_instrument_data: Dominio de valores de longitud de onda en los que mide un mismo
                            instrumento.
    '''
    lambda0_data = Lambda0_Dom(z, lambda_instrument_data)
    emission_data = H_lines(lambda0_data, blackbody(lambda0_data ,T))
    spectrum = noise_generator(emission_data)
    return z, spectrum

# %%
#Dominio de longitud de onda
lambda_min_measured = 400 #valor mínimo de longitud de onda que mide el instrumento
lambda_max_measured = 900 #valor máximo de longitud de onda que mide el instrumento
N_lambda = 1000 #Número de datos de longitud de onda (relacionado con la nominal del instrumento)
lambda_instrument_data = np.linspace(lambda_min_measured, lambda_max_measured, N_lambda) * 1e-9

#Qué tanto se desvía el ruido de los datos
standar_dev = 5*10**12

# %%
#Generación de 5000 datos
N_spectra = 5000

np.random.seed(88) #para reproducir
T_values = np.random.uniform(3000, 15000, N_spectra)
z_values = np.random.uniform(0, 1, N_spectra)



spectra_data = np.zeros((N_spectra+1, N_lambda+1))
spectra_data[0, 1:] = lambda_instrument_data

for i in range(N_spectra):
    spectra_data[i+1,0], spectra_data[i+1,1:] = spectrum_generator(T_values[i], z_values[i], lambda_instrument_data)

# %%
# with h5py.File('SpectraData.h5', 'w') as f:
#     # Metadatos esenciales
#     f.attrs['title'] = "Synthetic Spectra Database"
#     f.attrs['contact'] = "apvargaslo@unal.edu.co"
#     f.attrs['description'] = f'Este archivo contiene {N_spectra} espectros sintéticos para longitudes de onda entre {lambda_min_measured} y {lambda_max_measured}, con valores de redshift z entre 0 y 1 y temperaturas entre 3000 y 15000 K.'

#     # Guardar el dominio común (solo una vez)
#     wavelength_ds = f.create_dataset('wavelength_domain', data=spectra_data[0, 1:])
#     wavelength_ds.attrs['description'] = f'Dominio de longitud de onda compartido para todos los espectros: {N_lambda} valores entre {lambda_min_measured} y {lambda_max_measured}.'
#     wavelength_ds.attrs['units'] = 'm'

#     redshift_ds = f.create_dataset('redshift_values', data=z_values)
#     redshift_ds.attrs['description'] = f'{N_spectra} valores de redshift entre 0 y 1, cada uno correspondiente a un espectro diferente.'

#     temperature_ds = f.create_dataset('temperature_values', data=T_values)
#     temperature_ds.attrs['description'] = f'{N_spectra} valores de temperatura entre 3000 K y 15000 K, cada uno correspondiente a un espectro diferente.'
#     temperature_ds.attrs['units'] = 'K'

#     spectra_grp = f.create_group('spectra')
#     for i in range(N_spectra):
#         # Crear dataset para cada espectro
#         spec_ds = spectra_grp.create_dataset(f'spec_{i}',
#                                            data=spectra_data[i+1, 1:])  # shape (1000,)
#         # METADATOS POR ESPECTRO
#         spec_ds.attrs['description'] = f'Espectro número {i}'
#         spec_ds.attrs['z'] = z_values[i]  # Redshift correspondiente
#         spec_ds.attrs['T'] = T_values[i]  # Temperatura correspondiente
#         spec_ds.attrs['units'] = 'W m^-3'

with h5py.File('SpectraData.h5', 'w') as f:
    f.create_dataset('lambda [m]', data=spectra_data[0, 1:])
    f.create_dataset('z', data=z_values)
    spectra_grp = f.create_group('spectra')
    for i in range(N_spectra):
        spec_ds = spectra_grp.create_dataset(f'spec_{i}',
                                           data=spectra_data[i+1, 1:])  # shape (1000,)
    f.create_dataset('T [K]', data=T_values)
    f.attrs['description'] = 'Espectros sintéticos con líneas H-alpha'

# %%
# Cargar datos desde HDF5 (igual que antes)
with h5py.File('SpectraData.h5', 'r') as f:
    spectra_group = f['spectra']
    x = np.array([spectra_group[f'spec_{i}'][:] for i in range(len(spectra_group))])
    #lambdaDom=f['wavelength_domain'][:]
    #y = f['redshift_values'][:]
    y = f['z'][:]

# Reshape para Conv1D: (muestras, longitud_onda, canales)
# X = X.reshape(-1, 1000, 1)  # 1000 puntos espectrales, 1 canal
#X = np.array([np.stack((lambdaDom,i), axis=-1) for i in x])

# # Split train/test (80/20)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=88)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Cargar tus datos (ajusta según tu estructura real)
with h5py.File('SpectraData.h5', 'r') as f:
    spectra_group = f['spectra']
    x = np.array([spectra_group[f'spec_{i}'][:] for i in range(len(spectra_group))])
    y = f['z'][:]  # Valores de redshift reales

# Preprocesamiento
# 1. Normalizar espectros (por muestra)
x_normalized = (x - np.mean(x, axis=1, keepdims=True)) / np.std(x, axis=1, keepdims=True)

# 2. Normalizar valores z (por si tienen rangos muy grandes)
y_scaler = StandardScaler()
y_normalized = y_scaler.fit_transform(y.reshape(-1, 1)).flatten()

# 3. Añadir dimensión de canal (necesaria para Conv1D)
x_reshaped = x_normalized[..., np.newaxis]  # Forma: (muestras, 1000, 1)

# Dividir datos
X_train, X_test, y_train, y_test = train_test_split(
    x_reshaped, y_normalized, test_size=0.2, random_state=42
)

# Construir modelo
model = Sequential([
    # Capas convolucionales para extraer características espectrales
    Conv1D(64, kernel_size=15, activation='relu', input_shape=(1000, 1)),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(128, kernel_size=10, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(256, kernel_size=5, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    # Capas densas para regresión
    Flatten(),
    Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.5),

    Dense(128, activation='relu'),
    Dropout(0.3),

    Dense(64, activation='relu'),

    # Capa de salida: 1 neurona para predecir z
    Dense(1)
])

# Compilar modelo
model.compile(optimizer='adam',
              loss='mse',  # Error cuadrático medio para regresión
              metrics=['mae'])  # Error absoluto medio

# Resumen del modelo
model.summary()

# Entrenamiento
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.1,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
    ]
)

# Evaluación
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"\nError Absoluto Medio en prueba: {test_mae:.4f}")

# Predicción de ejemplo
sample_index = 5
sample_spectrum = X_test[sample_index][np.newaxis, ...]
predicted_z_normalized = model.predict(sample_spectrum)
predicted_z = y_scaler.inverse_transform(predicted_z_normalized)

print(f"\nPredicción de ejemplo:")
print(predicted_z)
#print(f"Redshift real: {y_scaler.inverse_transform([y_test[sample_index]])[0]:.6f}")
#print(f"Redshift predicho: {predicted_z[0][0]:.6f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 986, 64)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 986, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 493, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 484, 128)       │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 484, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 242, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 238, 256)       │       164,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 238, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 119, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 30464)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     7,799,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,089,217 (30.86 MB)
#  Trainable params: 8,088,321 (30.85 MB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - loss: 19.6138 - mae: 3.0276 - val_loss: 1.8937 - val_mae: 0.8891 - learning_rate: 0.0010
# Epoch 2/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 2.4835 - mae: 1.0260 - val_loss: 1.7157 - val_mae: 0.8283 - learning_rate: 0.0010
# Epoch 3/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.8305 - mae: 0.8307 - val_loss: 1.5214 - val_mae: 0.7348 - learning_rate: 0.0010
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.5498 - mae: 0.6918 - val_loss: 1.3197 - val_mae: 0.6183 - learning_rate: 0.0010
# Epoch 5/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.4290 - mae: 0.6409 - val_loss: 1.2648 - val_mae: 0.5845 - learning_rate: 0.0010
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3733 - mae: 0.6261 - val_loss: 1.1932 - val_mae: 0.5579 - learning_rate: 0.0010
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3640 - mae: 0.6174 - val_loss: 1.1833 - val_mae: 0.5685 - learning_rate: 0.0010
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.2485 - mae: 0.5736 - val_loss: 1.1326 - val_mae: 0.5453 - learning_rate: 0.0010
# Epoch 9/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.2398 - mae: 0.5733 - val_loss: 1.1402 - val_mae: 0.5735 - learning_rate: 0.0010
# Epoch 10/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1745 - mae: 0.5471 - val_loss: 1.0267 - val_mae: 0.5171 - learning_rate: 0.0010
# Epoch 11/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1428 - mae: 0.5512 - val_loss: 1.0863 - val_mae: 0.5705 - learning_rate: 0.0010
# Epoch 12/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0584 - mae: 0.5057 - val_loss: 1.0382 - val_mae: 0.5580 - learning_rate: 0.0010
# Epoch 13/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.9891 - mae: 0.4762 - val_loss: 0.9521 - val_mae: 0.5110 - learning_rate: 0.0010
# Epoch 14/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.9475 - mae: 0.4513 - val_loss: 0.8696 - val_mae: 0.4745 - learning_rate: 0.0010
# Epoch 15/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8949 - mae: 0.4380 - val_loss: 0.8966 - val_mae: 0.5213 - learning_rate: 0.0010
# Epoch 16/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8328 - mae: 0.4188 - val_loss: 0.8693 - val_mae: 0.5120 - learning_rate: 0.0010
# Epoch 17/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8357 - mae: 0.4318 - val_loss: 0.8217 - val_mae: 0.4824 - learning_rate: 0.0010
# Epoch 18/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.7540 - mae: 0.3989 - val_loss: 0.7555 - val_mae: 0.4648 - learning_rate: 0.0010
# Epoch 19/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.7331 - mae: 0.4027 - val_loss: 0.7419 - val_mae: 0.4702 - learning_rate: 0.0010
# Epoch 20/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.7137 - mae: 0.3980 - val_loss: 0.7634 - val_mae: 0.5105 - learning_rate: 0.0010
# Epoch 21/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.6720 - mae: 0.3909 - val_loss: 0.7261 - val_mae: 0.4888 - learning_rate: 0.0010
# Epoch 22/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.6328 - mae: 0.3764 - val_loss: 0.6887 - val_mae: 0.4835 - learning_rate: 0.0010
# Epoch 23/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.5661 - mae: 0.3421 - val_loss: 0.6530 - val_mae: 0.4740 - learning_rate: 0.0010
# Epoch 24/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.5811 - mae: 0.3737 - val_loss: 0.6641 - val_mae: 0.4965 - learning_rate: 0.0010
# Epoch 25/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.5360 - mae: 0.3436 - val_loss: 0.6167 - val_mae: 0.4690 - learning_rate: 0.0010
# Epoch 26/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.5312 - mae: 0.3474 - val_loss: 0.6368 - val_mae: 0.4927 - learning_rate: 0.0010
# Epoch 27/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.5007 - mae: 0.3487 - val_loss: 0.6854 - val_mae: 0.5502 - learning_rate: 0.0010
# Epoch 28/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.6455 - mae: 0.4507 - val_loss: 0.5799 - val_mae: 0.4741 - learning_rate: 0.0010
# Epoch 29/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.5033 - mae: 0.3682 - val_loss: 0.6324 - val_mae: 0.5304 - learning_rate: 0.0010
# Epoch 30/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.4414 - mae: 0.3177 - val_loss: 0.6031 - val_mae: 0.5108 - learning_rate: 0.0010
# Epoch 31/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.4300 - mae: 0.3297 - val_loss: 0.5930 - val_mae: 0.5132 - learning_rate: 0.0010
# Epoch 32/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.4243 - mae: 0.3348 - val_loss: 0.5277 - val_mae: 0.4728 - learning_rate: 0.0010
# Epoch 33/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.3717 - mae: 0.2975 - val_loss: 0.5569 - val_mae: 0.5125 - learning_rate: 0.0010
# Epoch 34/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.3689 - mae: 0.3044 - val_loss: 0.5325 - val_mae: 0.4954 - learning_rate: 0.0010
# Epoch 35/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4046 - mae: 0.3226 - val_loss: 0.5209 - val_mae: 0.4614 - learning_rate: 0.0010
# Epoch 36/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.3809 - mae: 0.3065 - val_loss: 0.5194 - val_mae: 0.4708 - learning_rate: 0.0010
# Epoch 37/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.3736 - mae: 0.3060 - val_loss: 0.5279 - val_mae: 0.4678 - learning_rate: 0.0010
# Epoch 38/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.4476 - mae: 0.3629 - val_loss: 0.7658 - val_mae: 0.5830 - learning_rate: 0.0010
# Epoch 39/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.4843 - mae: 0.3670 - val_loss: 0.6501 - val_mae: 0.5067 - learning_rate: 0.0010
# Epoch 40/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.4731 - mae: 0.3314 - val_loss: 0.5938 - val_mae: 0.4624 - learning_rate: 0.0010
# Epoch 41/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.5401 - mae: 0.3832 - val_loss: 0.6078 - val_mae: 0.4838 - learning_rate: 0.0010
# Epoch 42/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4707 - mae: 0.3285 - val_loss: 0.6321 - val_mae: 0.5227 - learning_rate: 5.0000e-04
# Epoch 43/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.3619 - mae: 0.2663 - val_loss: 0.5588 - val_mae: 0.4773 - learning_rate: 5.0000e-04
# Epoch 44/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.3333 - mae: 0.2495 - val_loss: 0.5166 - val_mae: 0.4667 - learning_rate: 5.0000e-04
# Epoch 45/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.3158 - mae: 0.2658 - val_loss: 0.5280 - val_mae: 0.4885 - learning_rate: 5.0000e-04
# Epoch 46/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.2814 - mae: 0.2392 - val_loss: 0.5231 - val_mae: 0.4978 - learning_rate: 5.0000e-04
# Epoch 47/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.2471 - mae: 0.2292 - val_loss: 0.4641 - val_mae: 0.4657 - learning_rate: 5.0000e-04
# Epoch 48/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.2584 - mae: 0.2492 - val_loss: 0.4767 - val_mae: 0.4828 - learning_rate: 5.0000e-04
# Epoch 49/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2349 - mae: 0.2411 - val_loss: 0.4675 - val_mae: 0.4647 - learning_rate: 5.0000e-04
# Epoch 50/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.2226 - mae: 0.2433 - val_loss: 0.4506 - val_mae: 0.4673 - learning_rate: 5.0000e-04
# Epoch 51/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2263 - mae: 0.2471 - val_loss: 0.4646 - val_mae: 0.4836 - learning_rate: 5.0000e-04
# Epoch 52/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.2109 - mae: 0.2350 - val_loss: 0.4532 - val_mae: 0.4764 - learning_rate: 5.0000e-04
# Epoch 53/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1997 - mae: 0.2275 - val_loss: 0.3827 - val_mae: 0.4268 - learning_rate: 5.0000e-04
# Epoch 54/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1950 - mae: 0.2214 - val_loss: 0.4047 - val_mae: 0.4589 - learning_rate: 5.0000e-04
# Epoch 55/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.2011 - mae: 0.2334 - val_loss: 0.4705 - val_mae: 0.4885 - learning_rate: 5.0000e-04
# Epoch 56/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1881 - mae: 0.2191 - val_loss: 0.4480 - val_mae: 0.4723 - learning_rate: 5.0000e-04
# Epoch 57/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1896 - mae: 0.2127 - val_loss: 0.4148 - val_mae: 0.4527 - learning_rate: 5.0000e-04
# Epoch 58/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1940 - mae: 0.2199 - val_loss: 0.3558 - val_mae: 0.4064 - learning_rate: 5.0000e-04
# Epoch 59/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1907 - mae: 0.2178 - val_loss: 0.5213 - val_mae: 0.5486 - learning_rate: 5.0000e-04
# Epoch 60/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2137 - mae: 0.2359 - val_loss: 0.4709 - val_mae: 0.5031 - learning_rate: 5.0000e-04
# Epoch 61/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.2057 - mae: 0.2294 - val_loss: 0.5149 - val_mae: 0.5353 - learning_rate: 5.0000e-04
# Epoch 62/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2053 - mae: 0.2259 - val_loss: 0.4543 - val_mae: 0.4758 - learning_rate: 5.0000e-04
# Epoch 63/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1933 - mae: 0.2186 - val_loss: 0.4916 - val_mae: 0.5122 - learning_rate: 5.0000e-04
# Epoch 64/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1788 - mae: 0.2030 - val_loss: 0.4432 - val_mae: 0.4720 - learning_rate: 2.5000e-04
# Epoch 65/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1601 - mae: 0.1847 - val_loss: 0.4521 - val_mae: 0.4811 - learning_rate: 2.5000e-04
# Epoch 66/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1428 - mae: 0.1719 - val_loss: 0.4391 - val_mae: 0.4842 - learning_rate: 2.5000e-04
# Epoch 67/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1428 - mae: 0.1778 - val_loss: 0.4114 - val_mae: 0.4640 - learning_rate: 2.5000e-04
# Epoch 68/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1304 - mae: 0.1713 - val_loss: 0.3946 - val_mae: 0.4626 - learning_rate: 2.5000e-04
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4161 - mae: 0.4347
#
# Error Absoluto Medio en prueba: 0.4350
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
#
# Predicción de ejemplo:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-8-293686474.py in <cell line: 0>()
#      89
#      90 print(f"\nPredicción de ejemplo:")
# ---> 91 print(f"Redshift real: {y_scaler.inverse_transform([y_test[sample_index]])[0]:.6f}")
#      92 print(f"Redshift predicho: {predicted_z[0][0]:.6f}")
#
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X, copy)
#    1104
#    1105         copy = copy if copy is not None else self.copy
# -> 1106         X = check_array(
#    1107             X,
#    1108             accept_sparse="csr",
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1091                         "if it contains a single sample."
#    1092                     )
# -> 1093                 raise ValueError(msg)
#    1094
#    1095         if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[-0.519974].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.Input(shape=(1000,2)))

model.add(tf.keras.layers.Conv1D(64,3, padding = "same", activation='relu'))

model.add(tf.keras.layers.MaxPooling1D(2))

model.add(tf.keras.layers.Conv1D(128,3, padding = "same", activation='relu'))

model.add(tf.keras.layers.MaxPooling1D(2))

model.add(tf.keras.layers.Conv1D(256,3, padding = "same", activation='relu'))

model.add(tf.keras.layers.GlobalAveragePooling1D())

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(128, activation='relu'))

model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Dense(64,activation='relu'))

model.add(tf.keras.layers.Dense(1))

# %%
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_16 (Conv1D)              │ (None, 1000, 64)       │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 500, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_17 (Conv1D)              │ (None, 500, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 250, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_18 (Conv1D)              │ (None, 250, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_1      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 164,929 (644.25 KB)
#  Trainable params: 164,929 (644.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X, y, epochs=10)
# Out:
# Epoch 1/10
#  60/157 ━━━━━━━━━━━━━━━━━━━━ 18s 188ms/step - loss: nan - mae: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-47-461290606.py in <cell line: 0>()
# ----> 1 history = model.fit(X, y, epochs=10)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
# --> 371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     217                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218             ):
# --> 219                 opt_outputs = multi_step_on_iterator(iterator)
#     220                 if not opt_outputs.has_value():
#     221                     raise StopIteration
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1681     cancellation_context = cancellation.context()
#    1682     if cancellation_context is None:
# -> 1683       outputs = execute.execute(
#    1684           name.decode("utf-8"),
#    1685           num_outputs=num_outputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
X.shape
# Out:
# (5000, 1000, 2)
